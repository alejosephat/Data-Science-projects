# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Leemos la base de datos

# %%
df = pd.read_csv('/laptop_price.csv', encoding='latin-1')

# %% [markdown]
# **ANALISIS EXPLORATORIO Y LIMPIEZA**
#
# ---

# %%
df. df.join(pd.get_dummies(df.Company))

# %%
df = df.drop('Product', axis=1)

# %%
df = df.join(pd.get_dummies(df.TypeName))
df = df.drop('TypeName', axis=1)

# %% [markdown]
# Limpiamos los datos de resolucion, memoria y ram del string con split index y lambda

# %%
df['ScreenResolution'] = df.ScreenResolution.str.split(' ').apply(lambda x: x[-1])
df['Screen Width'] = df.ScreenResolution.str.split('x').apply(lambda x: x[0])
df['Screen Height'] = df.ScreenResolution.str.split('x').apply(lambda x: x[1])

# %%
df = df.drop('ScreenResolution', axis=1)

# %%
df['CPU Brand'] = df.Cpu.str.split(' ').apply(lambda x: x[0])
df['CPU Frecuency'] = df.Cpu.str.split(' ').apply(lambda x: x[-1])

# %%
df = df.drop('Cpu', axis=1)

# %%
df['CPU Frecuency'] = df['CPU Frecuency'].str[:-3]

# %%
df['Ram'] = df['Ram'].str[:-2]

# %%
Convertimos a INT los valores numericos que figuran como INT

# %%
df['Ram'] = df['Ram'].astype('int')
df['CPU Frecuency'] = df['CPU Frecuency'].astype('float')

# %%
df['Screen Width'] = df['Screen Width'].astype('int')
df['Screen Height'] = df['Screen Height'].astype('int')

# %%
df['Memory Amount'] = df.Memory.str.split(' ').apply(lambda x: x[0])
df['Memory Type'] = df.Memory.str.split(' ').apply(lambda x: x[1])

# %% [markdown]
# Creamos una funcion para regularizar los valores del Memory Amount

# %%
def turn_memory_into_MB(value):
    if 'GB' in value:
      return float(value[:value.find('GB')]) * 1000
    elif 'TB' in value:
      return float(value[:value.find('TB')]) * 1000000

# %%
df['Memory Amount'] = df.Memory.apply(turn_memory_into_MB)
df = df.drop('Memory', axis=1)

# %%
df['Weight'] = df['Weight'].str[:-2]

# %%
df['Weight'] = df['Weight'].astype('float')

# %%
df['GPU Brand'] = df.Gpu.str.split(' ').apply(lambda x: x[0])

# %%
df = df.drop('Gpu', axis =1)

# %%
df = df.join(pd.get_dummies(df.OpSys))

df = df.drop('OpSys', axis=1)

# %%
cpu_categories = pd.get_dummies(df['CPU Brand'])
cpu_categories.columns = [col + '_CPU' for col in cpu_categories.columns]

df = df.join(cpu_categories)
df = df.drop('CPU Brand', axis=1)
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3       Intel
# 4       Intel
#         ...
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301    Intel
# 1302    Intel
# Name: CPU Brand, Length: 1303, dtype: object

# %%
gpu_categories = pd.get_dummies(df['GPU Brand'])
gpu_categories.columns = [col + '_GPU' for col in gpu_categories.columns]

df = df.join(gpu_categories)
df = df.drop('GPU Brand', axis=1)

# %%
df.corr()
# Out:
#                     laptop_ID    Inches       Ram    Weight  Price_euros  \
# laptop_ID            1.000000 -0.087796 -0.028607 -0.011798     0.067830
# Inches              -0.087796  1.000000  0.237993  0.827631     0.068197
# Ram                 -0.028607  0.237993  1.000000  0.383874     0.743007
# Weight              -0.011798  0.827631  0.383874  1.000000     0.210370
# Price_euros          0.067830  0.068197  0.743007  0.210370     1.000000
# Acer                -0.057721  0.009435 -0.138432  0.056444    -0.208349
# Apple               -0.119585 -0.158850  0.023950 -0.138191     0.080688
# Asus                -0.044252  0.112766  0.088634  0.101332    -0.010376
# Chuwi               -0.043348 -0.017426 -0.035117 -0.022536    -0.055646
# Dell                -0.013628  0.045288  0.082241  0.088465     0.048509
# Fujitsu              0.009268  0.019637 -0.016214  0.014053    -0.027135
# Google              -0.012039 -0.091551  0.021591 -0.067790     0.038086
# ...

# %%
plt.figure(figsize=(18,15))
sns.heatmap(df.corr(), annot = True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# Seleccionamos solamente las columnas con correlacion con el precio

# %%
target_correlation = df.corr()['Price_euros'].apply(abs).sort_values()

# %%
target_correlation
# Out:
# Xiaomi                0.000776
# Asus                  0.010376
# Mac OS X              0.015656
# Huawei                0.016851
# Windows 10 S          0.018312
# ARM_GPU               0.018431
# Fujitsu               0.027135
# Lenovo                0.029007
# Samsung               0.034584
# Google                0.038086
# Android               0.038700
# Toshiba               0.040339
# HP                    0.041291
# Microsoft             0.047562
# Dell                  0.048509
# Chuwi                 0.055646
# LG                    0.067053
# laptop_ID             0.067830
# Inches                0.068197
# Vero                  0.071972
# 2 in 1 Convertible    0.072675
# Apple                 0.080688
# Mediacom              0.087161
# macOS                 0.089928
# Netbook               0.097572
# Chrome OS             0.118684
# Memory Amount         0.122365
# Windows 10            0.137048
# Windows 7             0.152381
# Linux                 0.162060
# ...

# %%
selected_features = target_correlation[-21:].index
selected_features = list(selected_features)
selected_features
# Out:
# ['Memory Amount',
#  'Windows 10',
#  'Windows 7',
#  'Linux',
#  'No OS',
#  'MSI',
#  'Intel_GPU',
#  'AMD_GPU',
#  'Acer',
#  'Weight',
#  'Razer',
#  'Workstation',
#  'Ultrabook',
#  'Nvidia_GPU',
#  'Gaming',
#  'CPU Frecuency',
#  'Notebook',
#  'Screen Height',
#  'Screen Width',
#  'Ram',
#  'Price_euros']

# %%
limited_df = df[selected_features]
limited_df
# Out:
#       Memory Amount  Windows 10  Windows 7  Linux  No OS  MSI  Intel_GPU  \
# 0          128000.0           0          0      0      0    0          1
# 1          128000.0           0          0      0      0    0          1
# 2          256000.0           0          0      0      1    0          1
# 3          512000.0           0          0      0      0    0          0
# 4          256000.0           0          0      0      0    0          1
# ...             ...         ...        ...    ...    ...  ...        ...
# 1298       128000.0           1          0      0      0    0          1
# 1299       512000.0           1          0      0      0    0          1
# 1300        64000.0           1          0      0      0    0          1
# 1301      1000000.0           1          0      0      0    0          0
# 1302       500000.0           1          0      0      0    0          1
#
#       AMD_GPU  Acer  Weight  ...  Workstation  Ultrabook  Nvidia_GPU  Gaming  \
# ...

# %%
plt.figure(figsize=(18, 15))
sns.heatmap(limited_df.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# **Aplicamos el modelo RandomForest a las columnas escogidas.**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

X, y = limited_df.drop('Price_euros', axis=1), limited_df['Price_euros']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_sacled = scaler.transform(X_test)

# %%
forest = RandomForestRegressor()

forest.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_sacled, y_test)
# Out:
# 0.7970548161633256

# %%
y_pred = forest.predict(X_test_sacled)

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_pred, y_test)
plt.plot(range(0, 5000), range(0, 5000), c='red')

# %% [markdown]
# Se logra concluir el modelo con una precision de 0.7970548161633256, el cual puede mejorarse con una limpieza mas extensiva de los datos y/o incluyendo mas variables a nuestro modelo.
